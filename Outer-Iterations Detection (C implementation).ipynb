# %% [markdown]
# # Content
#
# In this notebook we detail the technique for automatically detecting outer-iterations.
# This can be done by a simple cross-correlation (as done for the paper) but combining this with some signal processing techniques the computations can be really faster and we think it is worth using them.

# %% [markdown]
# # Imports and Globals
#
# Here are the python packages that must be available to run the script.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import hilbert, sosfiltfilt, butter
from tools import pearson_xcorr

# %% [markdown]
# Below are the global path variables where are stored curves and pre-computed data (from other notebooks).
# Please adapt to your personnal installation.

# %%
# adapt here the pathes to your configuration (be sure directories exist)
curve_directory = './data'
tmp_directory = './tmp'
curve_filename  = 'bike_cortexm4_20_traces.npy'

# %% [markdown]
# # A First Glance at Outer-Iterations

# %%
curves = np.load(os.path.join(curve_directory,curve_filename))[:20]
mean_curve_full = np.mean(curves,axis=0)

# %%
fig,axes = plt.subplots(1,2,figsize=[16,4])
axes[0].plot(mean_curve_full)
axes[0].set_title("Mean curve")
axes[1].plot(curves[0])
axes[1].set_title("Single (first) curve")
plt.show()

# %% [markdown]
# We can observe some particular patterns in the second half of the curve.
# The fact is that the decoding algorithm uses 7 iterations to reach a zero syndrome but it turns out that the 3 last are useless in an overwelming proportion of the traces.
# Indeed, once the syndrome vanishes, all operations on it will leak far less and this is why we have such singular patterns where roughly part of the computations just seems to disappear.
#
# Let us make some rough delimitation of those 7 outer iterations.

# %%
rough_outer_starts = [4680000,10750000,16650000,22600000,28670000,34520000,40640000,46840000]
# rough_outer_starts = [4680000,10750000,16650000,22600000,28670000,34520000,40640000,46900000]
fig = plt.figure(figsize=[16,4])
ax = fig.gca()
ax.plot(curves[0])
ax.vlines(rough_outer_starts, ymin=-135, ymax=145, color='red')
ax.set_title("Single (first) curve with (rough) iteration separators")
plt.show()

# %% [markdown]
# As one can see, the patterns corresponding to a non-zero syndrome strongly differ from the one with a zero syndrome.

# %% [markdown]
# # Prelude Pattern to Outer-Iterations
#
# We can see that before each outer iteration starts there is a *big pattern*.
# We manually adjust our rough estimates `rough_outer_starts` on some outer iterations of the first curve to plot the corresponding *big patterns*.

# %%
fig, axes = plt.subplots(9,1,figsize=[32,32])
# bruh = 50000
bruh = 0
delta = 69830
# delta = 0
# zoom = 0
# zoom = -50000
zoom = 66390-150000*4+540000-2000+10000
# zoom = 66390-150000*4+540000-2000+10000+48500
# zoom_right = -4850+300-200000
zoom_right = -4850+300-1000
# decal = 150000*4
decal = 0
axes[0].plot(curves[0,4680000-99600+zoom-decal:4680000-99600+delta+bruh+zoom_right-decal])
ll = len(curves[0][4680000-99600+zoom-decal:4680000-99600+delta+bruh+zoom_right-decal])
axes[0].set_title("First curve big pattern n°1")
axes[1].plot(curves[0,10750000-77200+zoom-decal:10750000-77200+delta+bruh+zoom_right-decal])
axes[1].set_title("First curve big pattern n°2")
axes[2].plot(curves[0,16650000-50050+zoom-decal:16650000-50050+delta+bruh+zoom_right-decal])
axes[2].set_title("First curve big pattern n°3")
axes[3].plot(curves[0,22600000-71400+zoom-decal:22600000-71400+delta+bruh+zoom_right-decal])
axes[3].set_title("First curve big pattern n°4")
axes[4].plot(curves[0,28670000-49700+zoom-decal:28670000-49700+delta+bruh+zoom_right-decal])
axes[4].set_title("First curve big pattern n°5")
print(34712500+zoom-decal)
axes[5].plot(curves[0,34100736:34100736+ll+bruh])
axes[5].set_title("First curve bad big pattern n°6")
axes[6].plot(curves[0,34712500+zoom-decal:34712500+delta+bruh+zoom_right-decal])
axes[6].set_title("First curve big pattern n°6")
axes[7].plot(curves[0,40805000+zoom-decal:40805000+delta+bruh+zoom_right-decal])
axes[7].set_title("First curve big pattern n°7")
axes[8].plot(curves[0,46896000+zoom-decal:46896000+delta+bruh+zoom_right-decal])
axes[8].set_title("First curve big pattern n°8")
# 34100736 49390
plt.show()
# Out:
# 34726890

# %% [markdown]
# We see that there are two patterns possibly linked for non-zero and zero syndromes.

# %%
pattern = curves[0][4680000-99600+zoom-decal:4680000-99600+delta+bruh+zoom_right-decal]
fig = plt.figure(figsize=[16,4])
ax = fig.gca()
ax.plot(pattern)
ax.set_title("Selected pattern")
plt.show()
np.save(os.path.join(tmp_directory,'raw_outer_iteration_pattern.npy'),pattern)
print(len(pattern))
# Out:
# 49890

# %%
pattern_bis = curves[0][34712500+zoom-decal:34712500+delta+bruh+zoom_right-decal]
fig = plt.figure(figsize=[16,4])
ax = fig.gca()
ax.plot(pattern_bis)
ax.set_title("Selected pattern_bis")
plt.show()
np.save(os.path.join(tmp_directory,'raw_outer_iteration_pattern_bis.npy'),pattern_bis)
print(len(pattern_bis))
# Out:
# 49890

# %% [markdown]
# # Signal processing
#
# However, this pattern is very large and computing cross-correlation on the full trace will be time consumming.
# The shape of the pattern is similar to series of bursts in a radio signal and the position and length of these bursts seems to be a relevant characteristic to look at.
#
# We thus can try to restrict this signal to its shape. This can be done by applying a filter on its envelop as shown below.

# %%
env_pattern = np.abs(hilbert(pattern))
sos = butter(4, 0.01, output='sos')
proc_pattern = sosfiltfilt(sos, env_pattern)
fig, axes = plt.subplots(2,1,figsize=(16,4))
axes[0].plot(env_pattern)
axes[0].set_title('Pattern envelop')
axes[1].plot(proc_pattern)
axes[1].set_title('Filtered pattern envelop')
plt.show()

# %%
env_pattern_bis = np.abs(hilbert(pattern_bis))
sos = butter(4, 0.01, output='sos')
proc_pattern_bis = sosfiltfilt(sos, env_pattern_bis)
fig, axes = plt.subplots(2,1,figsize=(16,4))
axes[0].plot(env_pattern_bis)
axes[0].set_title('Pattern_bis envelop')
axes[1].plot(proc_pattern_bis)
axes[1].set_title('Filtered pattern_bis envelop')
plt.show()

# %% [markdown]
# We see that there is far too much samples to describe these patterns shape and thus propose to drastically decrease the correlation complexity by using decimation keeping a single point among 256.

# %%
win_size = 2**8
dec_pattern = np.array([ proc_pattern[i] for i in range(0,len(proc_pattern),win_size) ])
dec_pattern_bis = np.array([ proc_pattern_bis[i] for i in range(0,len(proc_pattern_bis),win_size) ])
fig, axes = plt.subplots(2,1,figsize=(16,6))
axes[0].plot(dec_pattern)
axes[0].set_title('Decimated pattern (1 point among {})'.format(win_size))
axes[1].plot(dec_pattern_bis)
axes[1].set_title('Decimated pattern_bis (1 point among {})'.format(win_size))
plt.show()

# %% [markdown]
# We see that the decimation does not decrease so much the shape of the pattern and thus we will use this pre-processing before computing cross-correlation.
#
# The same has to be done on the curve for the curve and the pattern to be comparable.

# %%
env_curve = np.abs(hilbert(curves[0]))
sos = butter(4, 0.01, output='sos')
proc_curve = sosfiltfilt(sos, env_curve)
dec_curve = np.array([ proc_curve[i] for i in range(0,len(proc_curve),win_size) ])
fig, axes = plt.subplots(3,1,figsize=(16,6))
axes[0].plot(env_curve)
axes[0].set_title('Curve envelop')
axes[1].plot(proc_curve)
axes[1].set_title('Filtered curve envelop')
axes[2].plot(dec_curve)
axes[2].set_title('Decimation of the filtered curve envelop')
plt.show()

# %% [markdown]
# # Cross-Correlation
#
# Let us now take a look at the result of the cross-correlation between the pattern and the curve.
# Due to our pre-processing step, the computation is a matter of seconds instead of minutes.

# %%
# %%time
pcc = pearson_xcorr(dec_curve,dec_pattern)
fig = plt.figure(figsize=[16,4])
ax = fig.gca()
ax.plot(pcc)
ax.set_title('Cross-correlation between the pre-processed pattern and curve.')
plt.show()
# Out:
# CPU times: user 5.77 s, sys: 24.5 ms, total: 5.79 s
# Wall time: 5.81 s

# %%
# %%time
pcc2 = pearson_xcorr(dec_curve,dec_pattern_bis)
fig = plt.figure(figsize=[16,4])
ax = fig.gca()
ax.plot(pcc2)
ax.set_title('Cross-correlation between the pre-processed pattern_bis and curve.')
plt.show()
# Out:
# CPU times: user 5.74 s, sys: 16 ms, total: 5.75 s
# Wall time: 5.79 s

# %% [markdown]
# We clearly see high peaks as expected. However for the 4 iterations with non-zero syndrome the pattern seems to appear twice. Let us take a look at the corresponding neighbourhoods of those peaks to see which are the one actually corresponding to the beginning of the outer iteration.

# %%
detected_peaks = np.where(pcc>0.8)[0]
detected_peaks_bis = np.where(pcc2>0.8)[0]
print(len(detected_peaks))
print(len(detected_peaks_bis))
all_detected_peaks = np.sort(np.concatenate((detected_peaks, detected_peaks_bis)))
all_detected_peaks_without_repetition = all_detected_peaks[0:1]
for i in range(1, len(all_detected_peaks)):
    if all_detected_peaks[i] - all_detected_peaks_without_repetition[-1] < 100:
        continue
    all_detected_peaks_without_repetition = np.concatenate((all_detected_peaks_without_repetition, all_detected_peaks[i:i+1]))
all_detected_peaks_without_repetition
# Out:
# 17
# 10
# array([ 17948,  39302,  41747,  62454,  64900,  85612,  88059, 109409,
#        111854, 133206, 135651, 157004, 159449, 180799, 183243])

# %%
fig, axes = plt.subplots(len(all_detected_peaks_without_repetition),1,figsize=(16,4*len(all_detected_peaks_without_repetition)))
for i, p in enumerate(all_detected_peaks_without_repetition):
    print(win_size*p)
    axes[i].plot(curves[0][win_size*p:win_size*p+len(pattern)+200000])
plt.show()
# Out:
# 4594688
# 10061312
# 10687232
# 15988224
# 16614400
# 21916672
# 22543104
# 28008704
# 28634624
# 34100736
# 34726656
# 40193024
# 40818944
# 46284544
# 46910208

# %% [markdown]
# <!-- It is clear now that the first of each couple of peaks is not the one we are looking for. In the case two peaks are separated by less than 2500 points (actually the gap is close to 2445) then we chose the second. -->
# It is clear now that we detect the gf2x_mod_mul from the code, se we will use them to separate the outer-iterations since these operations are the beginning or the end of the iterations.

# %% [markdown]
# # Testing other curves
#
# We have a technique working for the first curve based on a pattern taken from the first curve.
# Let us now see if it also works for others.

# %%
sos = butter(4, 0.01, output='sos')
decimation = 2**8
def pre_proc(curve, win_size=decimation):
    """Apply our pre-processing to a curve with decimation parapeterized by `win_size` parameter."""
    env_curve = np.abs(hilbert(curve))
    proc_curve = sosfiltfilt(sos, env_curve)
    dec_curve = np.array([ proc_curve[i] for i in range(0,len(proc_curve),win_size) ])
    return dec_curve

def detect_peaks(correlation, correlation_bis, threshold=0.8, min_gap=200):
    """Detects peaks in a correlation result ensuring that at least `mean_gap` samples separates the peaks."""
    detected_peaks = np.where(correlation>threshold)[0]
    detected_peaks2 = np.where(correlation_bis>threshold)[0]
    if len(detected_peaks) == 0:
        res = []
    else:
        res = [detected_peaks[0]]
        for i in range(1, len(detected_peaks)):
            if detected_peaks[i] - res[-1] < min_gap:
                if detected_peaks[i] > res[-1]:
                    res[-1] = detected_peaks[i]
                continue
            res = np.concatenate((res, detected_peaks[i:i+1]))

    if len(detected_peaks2) == 0:
        res2 = []
    else:
        res2 = [detected_peaks2[0]]
        for i in range(1, len(detected_peaks2)):
            if detected_peaks2[i] - res2[-1] < min_gap:
                if detected_peaks2[i] > res2[-1]:
                    res2[-1] = detected_peaks2[i]
                continue
            res2 = np.concatenate((res2, detected_peaks2[i:i+1]))
    

    return res, res2

# %%
outer_iterations_bounds = []
fig, axes = plt.subplots(len(curves),1,figsize=(16,4*len(curves)))
for i, curve in enumerate(curves):
    pcc = pearson_xcorr(pre_proc(curve),dec_pattern)
    pcc2 = pearson_xcorr(pre_proc(curve),dec_pattern_bis)
    (res, res2) = detect_peaks(pcc, pcc2)
    res_tot = np.sort(np.concatenate((res, res2)))
    outer_iterations_bounds.append(res_tot)
    axes[i].plot(pcc)
    axes[i].plot(pcc2)
    axes[i].scatter(res,[pcc[r] for r in res],color='red')
    axes[i].scatter(res2,[pcc2[r] for r in res2],color='red')
plt.show()
np.save(os.path.join(tmp_directory,'outer_iterations_bounds.npy'),decimation*np.array(outer_iterations_bounds))
